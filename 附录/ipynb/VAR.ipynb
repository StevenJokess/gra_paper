# %%
import warnings
warnings.simplefilter('ignore')

get_ipython().run_line_magic('matplotlib', 'inline')

# %% [markdown]
# https://stackoverflow.com/questions/35595766/matplotlib-line-magic-causes-syntaxerror-in-python-script
#
# Line magics are only supported by the IPython command line. They cannot simply be used inside a script, because %something is not correct Python syntax.
#
# 行魔术仅由 IPython 命令行支持。 它们不能简单地在脚本中使用，因为% something 不是正确的 Python 语法。
#
# If you want to do this from a script you have to get access to the IPython API and then call the run_line_magic function.
#
# 如果您想从脚本中执行此操作，必须获得对 IPython API 的访问权，然后调用运行行魔术函数。
#
# Instead of %matplotlib inline, you will have to do something like this in your script:
#
# 代替% matplotlib inline，你必须在你的脚本中做这样的事情:
#
# from IPython import get_ipython
# get_ipython().run_line_magic('matplotlib', 'inline')

# %%
# 模型相关包
import statsmodels.api as sm
import statsmodels.stats.diagnostic
# 画图包
import matplotlib.pyplot as plt
# 其他包
import pandas as pd
import numpy as np

# %%
fig = plt.figure(figsize=(12,8))
plt.plot(changeXAUUSD,'r',label='XAU USD')
plt.plot(shfeXAU,'g',label='SHFE XAU')
plt.title('Correlation: ' + str(correlation))
plt.grid(True)
plt.axis('tight')
plt.legend(loc=0)
plt.ylabel('Price')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-5246984dd5e6> in <module>
# ----> 1 fig = plt.figure(figsize=(12,8))
#       2 plt.plot(changeXAUUSD,'r',label='XAU USD')
#       3 plt.plot(shfeXAU,'g',label='SHFE XAU')
#       4 plt.title('Correlation: ' + str(correlation))
#       5 plt.grid(True)
#
# NameError: name 'plt' is not defined

# %%
sd1_closed = pd.read_excel(io = 'D:\lunwen\\sd1_closed.xls')
print (sd1_closed.head(3))
print(type(sd1_closed))
# Out:
# date   closes1   closed1
# 0 2017-12-26  0.770714 -0.031710
# 1 2017-12-27 -0.917752  0.113512
# 2 2017-12-28  0.628920  0.255139
# <class 'pandas.core.frame.DataFrame'>

# %%
sd1_closed.columns = ['date','closes1','closed1']
sd1_closed['date'] = pd.to_datetime(sd1_closed['date'])
sd1_closed = sd1_closed.set_index('date')
print(sd1_closed['closes1'].head(3))
# Out:
# date
# 2017-12-26    0.770714
# 2017-12-27   -0.917752
# 2017-12-28    0.628920
# Name: closes1, dtype: float64

# %%
sd1_closed.loc['2018-3-22']
# Out:
# closes1   -0.532526
# closed1   -2.934976
# Name: 2018-03-22 00:00:00, dtype: float64

# %%
sd1_closed['date'].plot
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'date'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-a0cf7f0a9bda> in <module>
# ----> 1 sd1_closed['date'].plot
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2978             if self.columns.nlevels > 1:
#    2979                 return self._getitem_multilevel(key)
# -> 2980             indexer = self.columns.get_loc(key)
#    2981             if is_integer(indexer):
#    2982                 indexer = [indexer]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
# -> 2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2900         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2901         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'date'

# %%
sd1_closed['closes1'].plot

# %%
sd1_closed['closes1'].plot()

# %%
fig = plt.figure(figsize=(12,8))
plt.plot(sd1_closed['closes1'],'r',label='SHCI')
plt.plot(sd1_closed['closes1'],'g',label='DJIA')
plt.title('Correlation: ' + str(correlation))
plt.grid(True)
plt.axis('tight')
plt.legend(loc=0)
plt.ylabel('Price')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-f587572e011c> in <module>
#       2 plt.plot(sd1_closed['closes1'],'r',label='SHCI')
#       3 plt.plot(sd1_closed['closes1'],'g',label='DJIA')
# ----> 4 plt.title('Correlation: ' + str(correlation))
#       5 plt.grid(True)
#       6 plt.axis('tight')
#
# NameError: name 'correlation' is not defined

# %%
fig = plt.figure(figsize=(12,8))
plt.plot(sd1_closed['closes1'],'r',label='SHCI')
plt.plot(sd1_closed['closed1'],'g',label='DJIA')
plt.title('Correlation: ' + str(correlation))
plt.grid(True)
plt.axis('tight')
plt.legend(loc=0)
plt.ylabel('Price')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-a4daec459491> in <module>
#       2 plt.plot(sd1_closed['closes1'],'r',label='SHCI')
#       3 plt.plot(sd1_closed['closed1'],'g',label='DJIA')
# ----> 4 plt.title('Correlation: ' + str(correlation))
#       5 plt.grid(True)
#       6 plt.axis('tight')
#
# NameError: name 'correlation' is not defined

# %% [markdown]
# https://blog.csdn.net/mooncrystal123/article/details/86736397

# %%
sd1_closed.corr(method ='pearson')
# Out:
#           closes1   closed1
# closes1  1.000000  0.043838
# closed1  0.043838  1.000000

# %% [markdown]
# https://www.geeksforgeeks.org/python-pandas-dataframe-corr/
# https://pandas.pydata.org/pandas-docs/version/0.7.3/computation.html

# %%
correlation = sd1_closed.corr(method ='pearson')

# %%
str(correlation)
# Out:
# '          closes1   closed1\ncloses1  1.000000  0.043838\nclosed1  0.043838  1.000000'

# %%
sd1_closed.autocorr(method ='pearson')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-f8fbeba0a11a> in <module>
# ----> 1 sd1_closed.autocorr(method ='pearson')
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'autocorr'

# %%
fig = plt.figure(figsize=(12,8))
plt.plot(sd1_closed['closes1'],'r',label='SHCI')
plt.plot(sd1_closed['closed1'],'g',label='DJIA')
plt.title('Correlation: ' + str(correlation))
plt.grid(True)
plt.axis('tight')
plt.legend(loc=0)
plt.ylabel('Price')
plt.show()

# %%
adfResult = sm.tsa.stattools.adfuller(sd1_closed['closes1','closed1'],maxlags)
output = pd.DataFrame(index=['Test Statistic Value', "p-value", "Lags Used", "Number of Observations Used",
                                         "Critical Value(1%)", "Critical Value(5%)", "Critical Value(10%)"],
                                  columns=['value'])
 output['value']['Test Statistic Value'] = adfResult[0]
 output['value']['p-value'] = adfResult[1]
 output['value']['Lags Used'] = adfResult[2]
 output['value']['Number of Observations Used'] = adfResult[3]
 output['value']['Critical Value(1%)'] = adfResult[4]['1%']
 output['value']['Critical Value(5%)'] = adfResult[4]['5%']
 output['value']['Critical Value(10%)'] = adfResult[4]['10%']
# Out:
#   File "<ipython-input-17-3a2569b5647b>", line 5
#     output['value']['Test Statistic Value'] = adfResult[0]
#     ^
# IndentationError: unexpected indent

# %%
adfResult = sm.tsa.stattools.adfuller(sd1_closed['closes1','closed1'],maxlags)
output = pd.DataFrame(index=['Test Statistic Value', "p-value", "Lags Used", "Number of Observations Used","Critical Value(1%)", "Critical Value(5%)", "Critical Value(10%)"],columns=['value'])
 output['value']['Test Statistic Value'] = adfResult[0]
 output['value']['p-value'] = adfResult[1]
 output['value']['Lags Used'] = adfResult[2]
 output['value']['Number of Observations Used'] = adfResult[3]
 output['value']['Critical Value(1%)'] = adfResult[4]['1%']
 output['value']['Critical Value(5%)'] = adfResult[4]['5%']
 output['value']['Critical Value(10%)'] = adfResult[4]['10%']
# Out:
#   File "<ipython-input-18-1011aecd376f>", line 3
#     output['value']['Test Statistic Value'] = adfResult[0]
#     ^
# IndentationError: unexpected indent

# %%
adfResult = sm.tsa.stattools.adfuller(sd1_closed['closes1','closed1'],maxlags)
output = pd.DataFrame(index=['Test Statistic Value', "p-value", "Lags Used", "Number of Observations Used","Critical Value(1%)", "Critical Value(5%)", "Critical Value(10%)"],columns=['value'])
output['value']['Test Statistic Value'] = adfResult[0]
output['value']['p-value'] = adfResult[1]
output['value']['Lags Used'] = adfResult[2]
output['value']['Number of Observations Used'] = adfResult[3]
output['value']['Critical Value(1%)'] = adfResult[4]['1%']
output['value']['Critical Value(5%)'] = adfResult[4]['5%']
output['value']['Critical Value(10%)'] = adfResult[4]['10%']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('closes1', 'closed1')
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-19-7553e836262c> in <module>
# ----> 1 adfResult = sm.tsa.stattools.adfuller(sd1_closed['closes1','closed1'],maxlags)
#       2 output = pd.DataFrame(index=['Test Statistic Value', "p-value", "Lags Used", "Number of Observations Used","Critical Value(1%)", "Critical Value(5%)", "Critical Value(10%)"],columns=['value'])
#       3 output['value']['Test Statistic Value'] = adfResult[0]
#       4 output['value']['p-value'] = adfResult[1]
#       5 output['value']['Lags Used'] = adfResult[2]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2978             if self.columns.nlevels > 1:
#    2979                 return self._getitem_multilevel(key)
# -> 2980             indexer = self.columns.get_loc(key)
#    2981             if is_integer(indexer):
#    2982                 indexer = [indexer]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
# -> 2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2900         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2901         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('closes1', 'closed1')

# %%
adfResult = sm.tsa.stattools.adfuller(sd1_closed['closes1','closed1'],maxlags)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('closes1', 'closed1')
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-20-70ef48d2c7f2> in <module>
# ----> 1 adfResult = sm.tsa.stattools.adfuller(sd1_closed['closes1','closed1'],maxlags)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2978             if self.columns.nlevels > 1:
#    2979                 return self._getitem_multilevel(key)
# -> 2980             indexer = self.columns.get_loc(key)
#    2981             if is_integer(indexer):
#    2982                 indexer = [indexer]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
# -> 2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2900         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2901         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('closes1', 'closed1')

# %%
adfResult = sm.tsa.stattools.adfuller(sd1_closed['closes1','closed1'],30)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('closes1', 'closed1')
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-21-476c75514e7b> in <module>
# ----> 1 adfResult = sm.tsa.stattools.adfuller(sd1_closed['closes1','closed1'],30)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2978             if self.columns.nlevels > 1:
#    2979                 return self._getitem_multilevel(key)
# -> 2980             indexer = self.columns.get_loc(key)
#    2981             if is_integer(indexer):
#    2982                 indexer = [indexer]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
# -> 2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2900         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2901         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('closes1', 'closed1')

# %%
adfResult = sm.tsa.stattools.adfuller(sd1_closed['closes1',30)
# Out:
#   File "<ipython-input-22-6e24579ad74c>", line 1
#     adfResult = sm.tsa.stattools.adfuller(sd1_closed['closes1',30)
#                                                                  ^
# SyntaxError: invalid syntax

# %%
adfResult = sm.tsa.stattools.adfuller(sd1_closed['closes1'],30)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-06eaa81fabca> in <module>
# ----> 1 adfResult = sm.tsa.stattools.adfuller(sd1_closed['closes1'],30)
#
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\stattools.py in adfuller(x, maxlag, regression, autolag, store, regresults)
#     230                              'regression component')
#     231     elif maxlag > nobs // 2 - ntrend - 1:
# --> 232         raise ValueError('maxlag must be less than (nobs/2 - 1 - ntrend) '
#     233                          'where n trend is the number of included '
#     234                          'deterministic regressors')
#
# ValueError: maxlag must be less than (nobs/2 - 1 - ntrend) where n trend is the number of included deterministic regressors

# %%
adfResult = sm.tsa.stattools.adfuller(sd1_closed['closes1'],3)

# %%
print (adfResult)
# Out:
# (-4.205563411845501, 0.0006447570639954202, 3, 52, {'1%': -3.562878534649522, '5%': -2.918973284023669, '10%': -2.597393446745562}, 142.1598562497805)

# %%
from statsmodels.tsa.stattools import adfuller

temp = np.array(data)
t = adfuller(sd1_closed['closes1'])  # ADF检验
output=pd.DataFrame(index=['Test Statistic Value', "p-value", "Lags Used", "Number of Observations Used","Critical Value(1%)","Critical Value(5%)","Critical Value(10%)"],columns=['value'])
output['value']['Test Statistic Value'] = t[0]
output['value']['p-value'] = t[1]
output['value']['Lags Used'] = t[2]
output['value']['Number of Observations Used'] = t[3]
output['value']['Critical Value(1%)'] = t[4]['1%']
output['value']['Critical Value(5%)'] = t[4]['5%']
output['value']['Critical Value(10%)'] = t[4]['10%']
output
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-741c5bd9fe03> in <module>
#       1 from statsmodels.tsa.stattools import adfuller
#       2
# ----> 3 temp = np.array(data)
#       4 t = adfuller(sd1_closed['closes1'])  # ADF检验
#       5 output=pd.DataFrame(index=['Test Statistic Value', "p-value", "Lags Used", "Number of Observations Used","Critical Value(1%)","Critical Value(5%)","Critical Value(10%)"],columns=['value'])
#
# NameError: name 'data' is not defined

# %%
# coding=utf-8
from statsmodels.tsa.stattools import adfuller

temp = np.array(data)
t = adfuller(sd1_closed['closes1'])  # ADF检验
output=pd.DataFrame(index=['Test Statistic Value', "p-value", "Lags Used", "Number of Observations Used","Critical Value(1%)","Critical Value(5%)","Critical Value(10%)"],columns=['value'])
output['value']['Test Statistic Value'] = t[0]
output['value']['p-value'] = t[1]
output['value']['Lags Used'] = t[2]
output['value']['Number of Observations Used'] = t[3]
output['value']['Critical Value(1%)'] = t[4]['1%']
output['value']['Critical Value(5%)'] = t[4]['5%']
output['value']['Critical Value(10%)'] = t[4]['10%']
output
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-6519ab71b8c9> in <module>
#       2 from statsmodels.tsa.stattools import adfuller
#       3
# ----> 4 temp = np.array(data)
#       5 t = adfuller(sd1_closed['closes1'])  # ADF检验
#       6 output=pd.DataFrame(index=['Test Statistic Value', "p-value", "Lags Used", "Number of Observations Used","Critical Value(1%)","Critical Value(5%)","Critical Value(10%)"],columns=['value'])
#
# NameError: name 'data' is not defined

# %% [markdown]
# https://zhuanlan.zhihu.com/p/54985638

# %%
# coding=utf-8
from statsmodels.tsa.stattools import adfuller

t = adfuller(sd1_closed['closes1'])  # ADF检验
output=pd.DataFrame(index=['Test Statistic Value', "p-value", "Lags Used", "Number of Observations Used","Critical Value(1%)","Critical Value(5%)","Critical Value(10%)"],columns=['value'])
output['value']['Test Statistic Value'] = t[0]
output['value']['p-value'] = t[1]
output['value']['Lags Used'] = t[2]
output['value']['Number of Observations Used'] = t[3]
output['value']['Critical Value(1%)'] = t[4]['1%']
output['value']['Critical Value(5%)'] = t[4]['5%']
output['value']['Critical Value(10%)'] = t[4]['10%']
output
# Out:
#                                    value
# Test Statistic Value            -4.20556
# p-value                      0.000644757
# Lags Used                              3
# Number of Observations Used           52
# Critical Value(1%)              -3.56288
# Critical Value(5%)              -2.91897
# Critical Value(10%)             -2.59739

# %%
# coding=utf-8
from statsmodels.tsa.stattools import adfuller

t = adfuller(sd1_closed['closed1'])  # ADF检验
output=pd.DataFrame(index=['Test Statistic Value', "p-value", "Lags Used", "Number of Observations Used","Critical Value(1%)","Critical Value(5%)","Critical Value(10%)"],columns=['value'])
output['value']['Test Statistic Value'] = t[0]
output['value']['p-value'] = t[1]
output['value']['Lags Used'] = t[2]
output['value']['Number of Observations Used'] = t[3]
output['value']['Critical Value(1%)'] = t[4]['1%']
output['value']['Critical Value(5%)'] = t[4]['5%']
output['value']['Critical Value(10%)'] = t[4]['10%']
output
# Out:
#                                  value
# Test Statistic Value          -3.04227
# p-value                      0.0311315
# Lags Used                            2
# Number of Observations Used         53
# Critical Value(1%)            -3.56024
# Critical Value(5%)            -2.91785
# Critical Value(10%)            -2.5968

# %%
result = sm.tsa.stattools.coint(sd1_closed['closes1',sd1_closed['closed1'])
# Out:
#   File "<ipython-input-30-4bf69619bd9f>", line 1
#     result = sm.tsa.stattools.coint(sd1_closed['closes1',sd1_closed['closed1'])
#                                                                               ^
# SyntaxError: invalid syntax

# %%
result = sm.tsa.stattools.coint(sd1_closed['closes1'],sd1_closed['closed1'])

# %%
print (result)
# Out:
# (-4.242527688745139, 0.0031418990668942875, array([-4.10664876, -3.44947826, -3.1224619 ]))

# %%
md = sm.tsa.VAR(sd1_closed['closes1'],sd1_closed['closed1'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-cf8d27b474b6> in <module>
# ----> 1 md = sm.tsa.VAR(sd1_closed['closes1'],sd1_closed['closed1'])
#
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\vector_ar\var_model.py in __init__(self, endog, exog, dates, freq, missing)
#     523         super(VAR, self).__init__(endog, exog, dates, freq, missing=missing)
#     524         if self.endog.ndim == 1:
# --> 525             raise ValueError("Only gave one variable to VAR")
#     526         self.neqs = self.endog.shape[1]
#     527         self.n_totobs = len(endog)
#
# ValueError: Only gave one variable to VAR

# %%
md = sm.tsa.VAR(sd1_closed['closes1','closed1'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('closes1', 'closed1')
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-34-cc6012c53cef> in <module>
# ----> 1 md = sm.tsa.VAR(sd1_closed['closes1','closed1'])
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2978             if self.columns.nlevels > 1:
#    2979                 return self._getitem_multilevel(key)
# -> 2980             indexer = self.columns.get_loc(key)
#    2981             if is_integer(indexer):
#    2982                 indexer = [indexer]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
# -> 2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2900         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2901         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('closes1', 'closed1')

# %%
model. sm. tsa. VARMAx(sd1_closed, order=(1, 0), trend='c')
model result- model fit(maxiter 1000, disp=False)
print(model result summary())
# Out:
#   File "<ipython-input-35-3df4eb183f64>", line 2
#     model result- model fit(maxiter 1000, disp=False)
#                ^
# SyntaxError: invalid syntax

# %%
model = sm.tsa.VARMAx(sd1_closed, order=(1, 0), trend='c')
model result = model fit(maxiter 1000, disp=False)
print(model result summary())
# Out:
#   File "<ipython-input-36-04c3b2342347>", line 2
#     model result = model fit(maxiter 1000, disp=False)
#                ^
# SyntaxError: invalid syntax

# %%
model = sm.tsa.VARMAx(sd1_closed, order=(1, 0), trend='c')
model result = model.fit(maxiter 1000, disp=False)
print(model result summary())
# Out:
#   File "<ipython-input-37-6efe5b3708b6>", line 2
#     model result = model.fit(maxiter 1000, disp=False)
#                ^
# SyntaxError: invalid syntax

# %%
model = sm.tsa.VARMAx(sd1_closed, order = (1, 0), trend = 'c')
model result = model.fit(maxiter = 1000, disp = False)
print(model result summary())
# Out:
#   File "<ipython-input-38-c709bf5b8001>", line 2
#     model result = model.fit(maxiter = 1000, disp = False)
#                ^
# SyntaxError: invalid syntax

# %%
model = sm.tsa.VARMAx(sd1_closed, order = (1, 0), trend = 'c')
model_result = model.fit(maxiter = 1000, disp = False)
print(model_result summary())
# Out:
#   File "<ipython-input-39-5b5aebda782a>", line 3
#     print(model_result summary())
#                              ^
# SyntaxError: invalid syntax

# %%
model = sm.tsa.VARMAx(sd1_closed, order = (1, 0), trend = 'c')
model_result = model.fit(maxiter = 1000, disp = False)
print(model_result.summary())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-40-6908e1c53ddb> in <module>
# ----> 1 model = sm.tsa.VARMAx(sd1_closed, order = (1, 0), trend = 'c')
#       2 model_result = model.fit(maxiter = 1000, disp = False)
#       3 print(model_result.summary())
#
# AttributeError: module 'statsmodels.tsa.api' has no attribute 'VARMAx'

# %%
model = sm.tsa.VARMAX(sd1_closed, order = (1, 0), trend = 'c')
fitmod = model.fit(maxiter = 1000, disp = False)
print(model_result.summary())
# Out:
# Statespace Model Results
# ==================================================================================
# Dep. Variable:     ['closes1', 'closed1']   No. Observations:                   56
# Model:                             VAR(1)   Log Likelihood                -162.432
#                               + intercept   AIC                            342.864
# Date:                    Wed, 22 Apr 2020   BIC                            361.092
# Time:                            22:49:42   HQIC                           349.931
# Sample:                                 0
#                                      - 56
# Covariance Type:                      opg
# ===================================================================================
# Ljung-Box (Q):                31.76, 47.08   Jarque-Bera (JB):          2.53, 25.03
# Prob(Q):                        0.82, 0.21   Prob(JB):                   0.28, 0.00
# Heteroskedasticity (H):         1.95, 5.26   Skew:                     -0.48, -1.12
# Prob(H) (two-sided):            0.16, 0.00   Kurtosis:                   3.41, 5.40
#                          Results for equation closes1
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept     -0.0029      0.155     -0.019      0.985      -0.306       0.301
# L1.closes1     0.2447      0.094      2.599      0.009       0.060       0.429
# L1.closed1     0.4423      0.099      4.463      0.000       0.248       0.637
#                          Results for equation closed1
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept     -0.0331      0.280     -0.118      0.906      -0.582       0.516
# L1.closes1     0.2107      0.182      1.159      0.247      -0.146       0.567
# L1.closed1     0.0524      0.204      0.257      0.797      -0.347       0.452
#                                   Error covariance matrix
# ============================================================================================
#                                coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# sqrt.var.closes1             0.8310      0.108      7.729      0.000       0.620       1.042
# sqrt.cov.closes1.closed1    -0.0468      0.140     -0.335      0.738      -0.321       0.227
# sqrt.var.closed1             1.2755      0.131      9.748      0.000       1.019       1.532
# ============================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)

# %% [markdown]
# https://towardsdatascience.com/prediction-task-with-multivariate-timeseries-and-var-model-47003f629f9
# https://www.youtube.com/watch?v=_vQ0W_qXMxk 20:24

# %% [markdown]
# #建立对象，dataframe就是前面的data，varLagNum就是你自己定的滞后阶数
# orgMod = sm.tsa.VARMAX(dataframe,order=(varLagNum,0),trend='nc',exog=None)

# %%
resid = fitmod.resid
result = {'fitmod':fitmod,'resid':resid}

# %% [markdown]
# 获得模型残差

# %%
print (result)
# Out:
# {'fitmod': <statsmodels.tsa.statespace.varmax.VARMAXResultsWrapper object at 0x000001D2166CED08>, 'resid':              closes1   closed1
# date
# 2017-12-26  0.798705  0.009490
# 2017-12-27 -1.089399 -0.014094
# 2017-12-28  0.806196  0.475724
# 2017-12-29  0.063406 -0.589021
# 2018-01-02  1.377888  0.413076
# 2018-01-03  0.131576  0.146163
# 2018-01-04  0.167996  0.493202
# 2018-01-05 -0.209841  0.777530
# 2018-01-08  0.092609 -0.101491
# 2018-01-09  0.027145  0.332255
# 2018-01-10  0.023746 -0.081166
# 2018-01-11  0.077701  0.798043
# 2018-01-12 -0.275695  0.862319
# 2018-01-16  0.347549 -0.075861
# 2018-01-17  0.068347  1.125412
# 2018-01-18  0.265153 -0.456655
# 2018-01-19  0.332234  0.075961
# 2018-01-22  0.205940  0.490791
# 2018-01-23  0.955102 -0.091603
# 2018-01-24  0.059263 -0.080189
# 2018-01-25 -0.469696  0.483711
# 2018-01-26  0.119409  0.919521
# 2018-01-29 -1.427364 -0.735544
# 2018-01-30 -0.454213 -1.095292
# 2018-01-31  0.646845  0.592388
# 2018-02-01 -1.042277  0.204635
# 2018-02-02  0.615862 -2.311719
# 2018-02-05  1.754407 -4.530738
# 2018-02-06 -1.490200  2.448960
# 2018-02-07 -2.028848  0.539072
# 2018-02-08 -0.943524 -3.728213
# 2018-02-09 -1.865262  1.936245
# 2018-02-12  1.157551  2.510896
# 2018-02-13  0.040345 -0.059993
# 2018-02-14  0.139107  0.845721
# 2018-02-22  1.608894  0.549513
# 2018-02-23 -0.195585  0.933302
# 2018-02-26  0.466809  1.405753
# 2018-02-27 -2.123024 -1.473332
# 2018-02-28 -0.198679 -1.167185
# 2018-03-01  1.348794 -1.358115
# 2018-03-02  0.050556 -0.259756
# 2018-03-05  0.347783  1.544166
# 2018-03-06  0.382440 -0.016717
# 2018-03-07 -0.805910 -0.513090
# 2018-03-08  0.795333  0.544134
# 2018-03-09  0.280833  1.675022
# 2018-03-12 -0.328786 -0.800069
# 2018-03-13 -0.362054 -0.740247
# 2018-03-14 -0.144235 -0.822218
# 2018-03-15  0.574391  0.672062
# 2018-03-16 -0.846576  0.303275
# 2018-03-19  0.317762 -1.191560
# 2018-03-20  0.875139  0.516103
# 2018-03-21 -0.585605 -0.246652
# 2018-03-22 -0.377143 -2.830259}

# %%
result = statsmodels.stats.diagnostic.breaks_cusumolsresid(resid)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-45-2bedafa3e425> in <module>
# ----> 1 result = statsmodels.stats.diagnostic.breaks_cusumolsresid(resid)
#
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\sandbox\stats\diagnostic.py in breaks_cusumolsresid(olsresidual, ddof)
#    1407
#    1408     '''
# -> 1409     resid = olsresidual.ravel()
#    1410     nobs = len(resid)
#    1411     nobssigma2 = (resid**2).sum()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'ravel'

# %%
result = statsmodels.stats.diagnostic.breaks_cusumolsresid(resid)

# %%
md = sm.tsa.VAR(sd1_closed)
re = md.fit(2)
fevd = re.fevd(10)
# 打印出方差分解的结果
print(fevd.summary())
# 画图
fevd.plot(figsize=(12, 16))
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# FEVD for closes1
#       closes1   closed1
# 0    1.000000  0.000000
# 1    0.745182  0.254818
# 2    0.739411  0.260589
# 3    0.744016  0.255984
# 4    0.743648  0.256352
# 5    0.737847  0.262153
# 6    0.738385  0.261615
# 7    0.738214  0.261786
# 8    0.738021  0.261979
# 9    0.737899  0.262101
#
# FEVD for closed1
#       closes1   closed1
# 0    0.000907  0.999093
# 1    0.128375  0.871625
# 2    0.164574  0.835426
# 3    0.163839  0.836161
# 4    0.160344  0.839656
# 5    0.164367  0.835633
# 6    0.164387  0.835613
# 7    0.164366  0.835634
# 8    0.164365  0.835635
# 9    0.164458  0.835542
#
#
# None

# %% [markdown]
# 方差分解图

# %%
ax = fitmod.impulse_responses(terms, orthogonalized=True).plot(figsize=(12, 8))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-48-8425fedbdca4> in <module>
# ----> 1 ax = fitmod.impulse_responses(terms, orthogonalized=True).plot(figsize=(12, 8))
#       2 plt.show()
#
# NameError: name 'terms' is not defined

# %% [markdown]
# 7）脉冲响应图
# orthogonalized=True代表使用乔里斯基正交，这里很奇葩，官方文档没有加plt.show(),但是博主亲身试验，一定要加，不然画不出来。terms代表周期数。

# %%
ax = fitmod.impulse_responses(5, orthogonalized=True).plot(figsize=(12, 8))
plt.show()

# %%
result1 = statsmodels.stats.diagnostic.breaks_cusumolsresid(resid[1])
print (result1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 1
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-50-7a3136cf979b> in <module>
# ----> 1 result1 = statsmodels.stats.diagnostic.breaks_cusumolsresid(resid[1])
#       2 print (result1)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2978             if self.columns.nlevels > 1:
#    2979                 return self._getitem_multilevel(key)
# -> 2980             indexer = self.columns.get_loc(key)
#    2981             if is_integer(indexer):
#    2982                 indexer = [indexer]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
# -> 2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2900         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2901         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 1

# %%
results1 = statsmodels.stats.diagnostic.breaks_cusumolsresid(resid['closes1'])

# %% [markdown]
# 6）系数平稳检验：CUSUM检验
# 这里也注意，Python这里不像EVIEWS，python没有办法算AR根，弄不到AR根图，但是python可以进行cusum检验。返回3各变量，第2个是P-value值，记得我之前说的吗，cusum检验要无法拒绝原假设，也就是说P-value值要大于0.05
#
# 这里的resid就是前面模型的resid

# %%
print (results1)
# Out:
# (0.678113440098097, 0.7472929308021011, [(1, 1.63), (5, 1.36), (10, 1.22)])

# %%
resultd1 = statsmodels.stats.diagnostic.breaks_cusumolsresid(resid['closed1'])

# %%
print (resultd1)
# Out:
# (0.6184472242159064, 0.8389552782777725, [(1, 1.63), (5, 1.36), (10, 1.22)])

# %%
sd2_closed = pd.read_excel(io = 'D:\lunwen\\sd2_closed.xls')
sd2_closed.columns = ['date','closes2','closed2']
sd2_closed['date'] = pd.to_datetime(sd2_closed['date'])
sd2_closed = sd2_closed.set_index('date')
print(sd2_closed['closes2'].head(3))
# Out:
# date
# 2018-03-23   -3.392667
# 2018-03-26   -0.603885
# 2018-03-27    1.050731
# Name: closes2, dtype: float64

# %%
sd2_closed.corr(method ='pearson')sd2_closed.corr(method ='pearson')
correlation = sd2_closed.corr(method ='pearson')
fig = plt.figure(figsize=(12,8))
plt.plot(sd2_closed['closes2'],'r',label='SHCI')
plt.plot(sd2_closed['closed2'],'g',label='DJIA')
plt.title('Correlation: ' + str(correlation))
plt.grid(True)
plt.axis('tight')
plt.legend(loc=0)
plt.ylabel('Price')
plt.show()
# Out:
#   File "<ipython-input-60-a36cc50132fa>", line 1
#     sd2_closed.corr(method ='pearson')sd2_closed.corr(method ='pearson')
#                                                ^
# SyntaxError: invalid syntax

# %%
sd2_closed.corr(method ='pearson')
correlation = sd2_closed.corr(method ='pearson')
fig = plt.figure(figsize=(12,8))
plt.plot(sd2_closed['closes2'],'r',label='SHCI')
plt.plot(sd2_closed['closed2'],'g',label='DJIA')
plt.title('Correlation: ' + str(correlation))
plt.grid(True)
plt.axis('tight')
plt.legend(loc=0)
plt.ylabel('Price')
plt.show()

# %%
adfResult = sm.tsa.stattools.adfuller(sd2_closed['closes2'],3)
print (adfResult)

# coding=utf-8
from statsmodels.tsa.stattools import adfuller

t = adfuller(sd2_closed['closes2'])  # ADF检验
output=pd.DataFrame(index=['Test Statistic Value', "p-value", "Lags Used", "Number of Observations Used","Critical Value(1%)","Critical Value(5%)","Critical Value(10%)"],columns=['value'])
output['value']['Test Statistic Value'] = t[0]
output['value']['p-value'] = t[1]
output['value']['Lags Used'] = t[2]
output['value']['Number of Observations Used'] = t[3]
output['value']['Critical Value(2%)'] = t[4]['1%']
output['value']['Critical Value(5%)'] = t[4]['5%']
output['value']['Critical Value(20%)'] = t[4]['20%']
output

# coding=utf-8
from statsmodels.tsa.stattools import adfuller

t = adfuller(sd2_closed['closed2'])  # ADF检验
output=pd.DataFrame(index=['Test Statistic Value', "p-value", "Lags Used", "Number of Observations Used","Critical Value(1%)","Critical Value(5%)","Critical Value(10%)"],columns=['value'])
output['value']['Test Statistic Value'] = t[0]
output['value']['p-value'] = t[1]
output['value']['Lags Used'] = t[2]
output['value']['Number of Observations Used'] = t[3]
output['value']['Critical Value(2%)'] = t[4]['1%']
output['value']['Critical Value(5%)'] = t[4]['5%']
output['value']['Critical Value(20%)'] = t[4]['20%']
output
# Out:
# (-8.44971061733133, 1.6752012101963112e-13, 0, 58, {'1%': -3.548493559596539, '5%': -2.912836594776334, '10%': -2.594129155766944}, 165.1806200809679)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-62-4fc62c61091b> in <module>
#      13 output['value']['Critical Value(2%)'] = t[4]['1%']
#      14 output['value']['Critical Value(5%)'] = t[4]['5%']
# ---> 15 output['value']['Critical Value(20%)'] = t[4]['20%']
#      16 output
#      17
#
# KeyError: '20%'

# %%
adfResult = sm.tsa.stattools.adfuller(sd2_closed['closes2'],3)
print (adfResult)

# coding=utf-8
from statsmodels.tsa.stattools import adfuller

t = adfuller(sd2_closed['closes2'])  # ADF检验
output=pd.DataFrame(index=['Test Statistic Value', "p-value", "Lags Used", "Number of Observations Used","Critical Value(1%)","Critical Value(5%)","Critical Value(10%)"],columns=['value'])
output['value']['Test Statistic Value'] = t[0]
output['value']['p-value'] = t[1]
output['value']['Lags Used'] = t[2]
output['value']['Number of Observations Used'] = t[3]
output['value']['Critical Value(2%)'] = t[4]['1%']
output['value']['Critical Value(5%)'] = t[4]['5%']
output['value']['Critical Value(20%)'] = t[4]['10%']
output

# coding=utf-8
from statsmodels.tsa.stattools import adfuller

t = adfuller(sd2_closed['closed2'])  # ADF检验
output=pd.DataFrame(index=['Test Statistic Value', "p-value", "Lags Used", "Number of Observations Used","Critical Value(1%)","Critical Value(5%)","Critical Value(10%)"],columns=['value'])
output['value']['Test Statistic Value'] = t[0]
output['value']['p-value'] = t[1]
output['value']['Lags Used'] = t[2]
output['value']['Number of Observations Used'] = t[3]
output['value']['Critical Value(2%)'] = t[4]['1%']
output['value']['Critical Value(5%)'] = t[4]['5%']
output['value']['Critical Value(20%)'] = t[4]['10%']
output
# Out:
# (-8.44971061733133, 1.6752012101963112e-13, 0, 58, {'1%': -3.548493559596539, '5%': -2.912836594776334, '10%': -2.594129155766944}, 165.1806200809679)
#                                    value
# Test Statistic Value            -11.1554
# p-value                      2.87427e-20
# Lags Used                              0
# Number of Observations Used           58
# Critical Value(1%)                   NaN
# Critical Value(5%)                   NaN
# Critical Value(10%)                  NaN

# %%
adfResult = sm.tsa.stattools.adfuller(sd2_closed['closes2'],3)
print (adfResult)

# coding=utf-8
from statsmodels.tsa.stattools import adfuller

t = adfuller(sd2_closed['closes2'])  # ADF检验
output=pd.DataFrame(index=['Test Statistic Value', "p-value", "Lags Used", "Number of Observations Used","Critical Value(1%)","Critical Value(5%)","Critical Value(10%)"],columns=['value'])
output['value']['Test Statistic Value'] = t[0]
output['value']['p-value'] = t[1]
output['value']['Lags Used'] = t[2]
output['value']['Number of Observations Used'] = t[3]
output['value']['Critical Value(2%)'] = t[4]['1%']
output['value']['Critical Value(5%)'] = t[4]['5%']
output['value']['Critical Value(20%)'] = t[4]['10%']
output
# Out:
# (-8.44971061733133, 1.6752012101963112e-13, 0, 58, {'1%': -3.548493559596539, '5%': -2.912836594776334, '10%': -2.594129155766944}, 165.1806200809679)
#                                   value
# Test Statistic Value           -8.44971
# p-value                      1.6752e-13
# Lags Used                             0
# Number of Observations Used          58
# Critical Value(1%)                  NaN
# Critical Value(5%)                  NaN
# Critical Value(10%)                 NaN

# %%
# TODO

# %%
model = sm.tsa.VARMAX(sd2_closed, order = (1, 0), trend = 'c')
fitmod = model.fit(maxiter = 1000, disp = False)
print(model_result.summary())

resid = fitmod.resid
result = {'fitmod':fitmod,'resid':resid}

print (result)

# %%
md = sm.tsa.VAR(sd2_closed)
re = md.fit(2)
fevd = re.fevd(10)
# 打印出方差分解的结果
print(fevd.summary())
# 画图
fevd.plot(figsize=(12, 16))
plt.show()

# %%
results2 = statsmodels.stats.diagnostic.breaks_cusumolsresid(resid['closes2'])
print (results2)
resultd2 = statsmodels.stats.diagnostic.breaks_cusumolsresid(resid['closed2'])
print (resultd2)
