# %%
import warnings
warnings.simplefilter('ignore')

get_ipython().run_line_magic('matplotlib', 'inline')

# %% [markdown]
# https://stackoverflow.com/questions/35595766/matplotlib-line-magic-causes-syntaxerror-in-python-script
#
# Line magics are only supported by the IPython command line. They cannot simply be used inside a script, because %something is not correct Python syntax.
#
# 行魔术仅由 IPython 命令行支持。 它们不能简单地在脚本中使用，因为% something 不是正确的 Python 语法。
#
# If you want to do this from a script you have to get access to the IPython API and then call the run_line_magic function.
#
# 如果您想从脚本中执行此操作，必须获得对 IPython API 的访问权，然后调用运行行魔术函数。
#
# Instead of %matplotlib inline, you will have to do something like this in your script:
#
# 代替% matplotlib inline，你必须在你的脚本中做这样的事情:
#
# from IPython import get_ipython
# get_ipython().run_line_magic('matplotlib', 'inline')

# %%
from datetime import datetime
start = datetime(2017, 12, 22)
mid = datetime(2018, 3, 22)
end = datetime(2018, 6, 22)

# %%
import pandas_datareader.data as web
shci1 = web.DataReader("000001.SS", "yahoo", start,mid)
shci2 = web.DataReader("000001.SS", "yahoo",m id,end)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-960d055d48a9> in <module>
#       1 shci1 = web.DataReader("000001.SS", "yahoo",start,mid)
# ----> 2 shci2 = web.DataReader("000001.SS", "yahoo",mid,end)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     206                 else:
#     207                     kwargs[new_arg_name] = new_arg_value
# --> 208             return func(*args, **kwargs)
#     209
#     210         return wrapper
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas_datareader\data.py in DataReader(name, data_source, start, end, retry_count, pause, session, api_key)
#     385             retry_count=retry_count,
#     386             pause=pause,
# --> 387             session=session,
#     388         ).read()
#     389
#
# ...

# %%
djia1 = web.DataReader('^DJI', 'yahoo',start, mid)
djia2 = web.DataReader('^DJI', 'yahoo',mid, end)

# %% [markdown]
# web.DataReader('^DJI','yahoo')   # Dow
# https://stackoverflow.com/questions/23283111/grabbing-data-from-entire-index-e-g-djia-using-pandas-web-datareader

# %%
print (shci1.columns)
print (djia1.columns)
# Out:
# Index(['High', 'Low', 'Open', 'Close', 'Volume', 'Adj Close'], dtype='object')
# Index(['High', 'Low', 'Open', 'Close', 'Volume', 'Adj Close'], dtype='object')

# %%
print (shci1.describe())
print (djia1.describe())
# Out:
# High          Low         Open        Close         Volume  \
# count    59.000000    59.000000    59.000000    59.000000      59.000000
# mean   3370.244654  3329.158865  3348.359251  3352.690148  188815.254237
# std     104.949010   105.872242   103.784813   105.150111   42053.766134
# min    3168.125977  3062.742920  3128.371094  3129.851074  100300.000000
# 25%    3295.615967  3260.020020  3276.471436  3280.045532  150950.000000
# 50%    3333.561035  3293.441895  3314.031006  3309.260010  186400.000000
# 75%    3441.312500  3404.612915  3418.617554  3432.767456  217600.000000
# max    3587.031982  3534.195068  3563.639893  3559.465088  280600.000000
#
#          Adj Close
# count    59.000000
# mean   3352.690148
# std     105.150111
# min    3129.851074
# 25%    3280.045532
# 50%    3309.260010
# 75%    3432.767456
# max    3559.465088
#                High           Low          Open         Close        Volume  \
# ...

# %%
print (shci2.describe())
print (djia2.describe())
# Out:
# High          Low         Open        Close         Volume  \
# count    62.000000    62.000000    62.000000    62.000000      62.000000
# mean   3131.896291  3093.273831  3115.263786  3113.740864  144690.322581
# std      70.387532    78.739867    73.928381    75.421826   27553.713324
# min    2891.968994  2837.144043  2855.584961  2875.810059  108600.000000
# 25%    3098.972839  3057.064209  3083.758728  3080.145752  128000.000000
# 50%    3140.021973  3104.555420  3123.312988  3125.608521  139250.000000
# 75%    3177.325195  3147.880066  3166.481018  3162.758728  154975.000000
# max    3288.797119  3242.761963  3281.264893  3263.479980  275500.000000
#
#          Adj Close
# count    62.000000
# mean   3113.740864
# std      75.421826
# min    2875.810059
# 25%    3080.145752
# 50%    3125.608521
# 75%    3162.758728
# max    3263.479980
#                High           Low          Open         Close        Volume  \
# ...

# %% [markdown]
# https://blog.csdn.net/weixin_44580977/article/details/101994640

# %%
print(shci1.info())
print(djia1.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 59 entries, 2017-12-22 to 2018-03-22
# Data columns (total 6 columns):
# High         59 non-null float64
# Low          59 non-null float64
# Open         59 non-null float64
# Close        59 non-null float64
# Volume       59 non-null int64
# Adj Close    59 non-null float64
# dtypes: float64(5), int64(1)
# memory usage: 3.2 KB
# None
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 62 entries, 2017-12-21 to 2018-03-22
# Data columns (total 6 columns):
# High         62 non-null float64
# Low          62 non-null float64
# Open         62 non-null float64
# Close        62 non-null float64
# Volume       62 non-null int64
# Adj Close    62 non-null float64
# dtypes: float64(5), int64(1)
# memory usage: 3.4 KB
# None

# %%
print(shci2.info())
print(djia2.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 62 entries, 2018-03-22 to 2018-06-22
# Data columns (total 6 columns):
# High         62 non-null float64
# Low          62 non-null float64
# Open         62 non-null float64
# Close        62 non-null float64
# Volume       62 non-null int64
# Adj Close    62 non-null float64
# dtypes: float64(5), int64(1)
# memory usage: 3.4 KB
# None
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 66 entries, 2018-03-21 to 2018-06-22
# Data columns (total 6 columns):
# High         66 non-null float64
# Low          66 non-null float64
# Open         66 non-null float64
# Close        66 non-null float64
# Volume       66 non-null int64
# Adj Close    66 non-null float64
# dtypes: float64(5), int64(1)
# memory usage: 3.6 KB
# None

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style('darkgrid')
plt.rc("figure", figsize=(16, 6))
plt.rc("savefig", dpi=90)
plt.rc("font",family="sans-serif")
plt.rc("font",size=14)

#绘制收盘价
djia1.Close.plot(c='b')
plt.legend(['Close','30ave','60ave'],loc='best')
plt.show()

# %%
djia2.Close.plot(c='b')
plt.legend(['Close','30ave','60ave'],loc='best')
plt.show()

# %%
shci1.Close.plot(c='b')
plt.legend(['Close','30ave','60ave'],loc='best')
plt.show()

# %%
shci2.Close.plot(c='b')
plt.legend(['Close','30ave','60ave'],loc='best')
plt.show()

# %%
returns_shci1 = 100 * shci1['Close'].pct_change().dropna()
returns_djia1 = 100 * djia1['Close'].pct_change().dropna()
returns_shci2 = 100 * shci2['Close'].pct_change().dropna()
returns_djia2 = 100 * djia2['Close'].pct_change().dropna()

# %%
shci1.describe().to_excel('D:\lunwen\shci1.xls')
djia1.describe().to_excel('D:\lunwen\djia1.xls')
shci2.describe().to_excel('D:\lunwen\shci2.xls')
djia2.describe().to_excel('D:\lunwen\djia2.xls')

# %%
returns_shci1.to_excel('D:\lunwen\\returns_shci1.xls')
returns_djia1.to_excel('D:\lunwen\\returns_djia1.xls')
returns_shci2.to_excel('D:\lunwen\\returns_shci2.xls')
returns_djia2.to_excel('D:\lunwen\\returns_djia2.xls')
